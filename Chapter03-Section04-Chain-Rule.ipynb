# %% [markdown]
# ### Chapter 3, Section 4: The chain rule
# - This is one of the most useful tricks in engineering problems.
# - Problems: Paper (7, 9, 11, 13, 15, 17, 19, 25, 27, 29, 33, 41).

# %% [markdown]
# ![alt text](1000012772.jpg)
# ![alt text](1000012773.jpg)
# ![alt text](1000012774.jpg)
# ![alt text](1000012775.jpg)
# ![alt text](1000012776.jpg)
#
# ![alt text](1000012777.jpg)
# ![alt text](1000012778.jpg)
